# %% [markdown]
# # Polynomial regression demo

# %%
#directory "_build"
#load "matrix.cmo"
#require "jupyter-archimedes"
#use "matrix.ml"
#use "polynomial_regression.ml"

(* Generating training data for quadratic fit *)
let rec gen_x acc n = if n = 0 then acc else gen_x (Random.float 1.0 :: acc) (n-1) 
let x = gen_x [] 100
let rec gen_y acc lst = 
    match lst with 
    | [] -> acc 
    | x :: xs -> gen_y (acc @ [2.6 *. x ** 2. -. 3.14 *. x -. 1.3 +. (Random.float 0.3)]) xs 
let y = gen_y [] x
let rec gen_pp acc x_lst y_lst = 
    match x_lst with 
    | [] -> acc 
    | x :: xs -> 
        match y_lst with 
        | [] -> assert false
        | y :: ys -> 
            gen_pp ((x, y) :: acc) xs ys
let pp = gen_pp [] x y

let x = [x] |> construct |> transpose 
let y = [y] |> construct |> transpose 
let w = fit x y 2 |> matrix

let f x = 
    match w with 
    | [a] :: [b] :: [c] :: [] -> a +. b *. x +. c *. x ** 2.
    | _ -> assert false
# Out:
# type t = { dimensions : int * int; matrix : float list list; }
# exception InvalidDimensions of string
# val dim : t -> int * int = <fun>
# val matrix : t -> float list list = <fun>
# val fill : int -> int -> float -> t = <fun>
# val zero : int -> int -> t = <fun>
# val eye : int -> t = <fun>
# val transpose : t -> t = <fun>
# val mult : t -> t -> t = <fun>
# val to_array : 'a list list -> 'a array array = <fun>
# val to_list : 'a array array -> 'a list list = <fun>
# val swap : 'a array -> int -> int -> unit = <fun>
# val rref : t -> t = <fun>
# val construct : float list list -> t = <fun>
# val lu_decomp : t -> t * t = <fun>
# val concat : t -> t -> t = <fun>
# val invert : t -> t = <fun>
# val scale : t -> float -> t = <fun>
# val det : t -> float = <fun>
# val magnitude : t -> float = <fun>
# val normalize : t -> t = <fun>
# val eigen : t -> bool -> float * t = <fun>
# val elem_pow : t -> float -> t = <fun>
# val pinv : t -> t = <fun>
# val op : t -> t -> (float -> float -> float) -> t = <fun>
# val dot : t -> t -> float = <fun>
# val w : Matrix.t ref = {contents = <abstr>}
# val fit : Matrix.t -> Matrix.t -> int -> Matrix.t = <fun>
# val predict : Matrix.t -> Matrix.t = <fun>
# val gen_x : float list -> int -> float list = <fun>
# val x : float list =
#   [0.600381512524197802; 0.130079591285448298; 0.190269279397970337;
#    0.386667208575989407; 0.0419180099458545466; 0.923740494661459577;
#    0.272364918580049409; 0.624303829659604; 0.925261605732592418;
#    0.733889514512473529; 0.561978263807455081; 0.460610508131040708;
#    0.19669996110265503; 0.28038826477236517; 0.749328819258752499;
#    0.102046066389680487; 0.0382617590706761657; 0.226610291935040425;
#    0.75046399217971; 0.672471530568904408; 0.0315332714975545;
#    0.744884175191259934; 0.899296062278436392; 0.0449577154203468;
#    0.194536100165994486; 0.0755656446037260288; 0.789216514262885749;
#    0.101509190297779522; 0.315349250245916868; 0.38540145940218723;
#    0.361478306890748058; 0.144899771754435081; 0.426178733323951342;
#    -1.22132070561686445; -1.52580494469957895; -2.08719834485355;
#    -1.97615323746901117; -1.56171682445711468; -1.81464868137449242;
#    -1.63583681095381794; -1.99751666423021645; -2.07690714713055602;
#    -1.81844887270709465; -1.76833420835345057; -2.13636296969191308;
#    -1.78389294771408724; -1.86645051088509928; -1.99985398368198908;
#    -1.97268052990999254; -1.93315560152924304; -1.17517203212530119;
#    -2.12072016623426096; -1.57921980872802403; -1.96476885749862751;
#    -2.11158375431290946; -1.6329313726718393; -2.02800497167885929;
#    -1.70313924373665038; -1.25418349154916275; -2.03098202062531685;
#    -1.84856276462921376; -1.28589285917724783; -1.95965662749819614;
#    -1.89206844595596246]
# val gen_pp : ('a * 'b) list -> 'a list -> 'b list -> ('a * 'b) list = <fun>
# val pp : (float * float) list =
#   [(0.827912695925094311, -1.89206844595596246);
#    (0.437356650832526561, -1.95965662749819614);
#    (0.0856192250943311, -1.28589285917724783);
#    (0.923949155798479, -1.84856276462921376);
#    (0.3778646872323011, -2.03098202062531685);
#    (0.085492524164425, -1.25418349154916275);
#    (0.250170063473949211, -1.70313924373665038);
#    (0.465050472045983099, -2.02800497167885929);
#    (0.962951508590020433, -1.6329313726718393);
#    (0.618815795920407807, -2.11158375431290946);
#    (0.643110987387888522, -1.96476885749862751);
#    (0.202892013881266098, -1.57921980872802403);
#    (0.758313936633271, -2.12072016623426096);
#    (0.00515804129692581329, -1.17517203212530119);
#    (0.774781426660801409, -1.93315560152924304);
#    (0.907463397124228854, -1.97268052990999254);
#    (0.824001652209124469, -1.99985398368198908);
#    (0.39042200929318116, -1.86645051088509928);
#    (0.958929259227562114, -1.78389294771408724);
#    (0.435221122370711644, -2.13636296969191308);
#    (0.918057953123441628, -1.76833420835345057);
#    (0.985214760368429365, -1.81844887270709465);
#    (0.521488356197265079, -2.07690714713055602);
#    (0.655605433682720395, -1.99751666423021645);
#    (0.203277060344363963, -1.63583681095381794);
#    (0.864708103680206341, -1.81464868137449242);
#    (0.169998844223382517, -1.56171682445711468);
#    (0.720596909937850749, -1.97615323746901117);
#    (0.67387663534491, -2.08719834485355);
#    (0.186344738530474452, -1.52580494469957895);
#    (0.0717249231975531643, -1.22132070561686445);
#    (0.516039440251339743, -2.00999548343293455);
#    (0.222879063526043975, -1.65797474354455576);
#    (0.154685457680294791, -1.51954249570656819);
#    (0.884370004021655109, -1.84684946143070405);
#    (0.381470885966226081, -2.01978767645694868);
#    (0.261310692765758801, -1.9196267536051681);
#    (0.410325504470645031, -1.88447184911281318);
#    (0.246699179675988228, -1.89398552580600454);
#    (0.0367442302950634209, -1.35239995751160857);
#    (0.143594351561359135, -1.43657301903828905);
#    (0.33839769369910111, -1.78875500899266848);
#    (0.686837415159475273, -2.16641802481969359);
#    (0.608265598889496495, -2.07112280814490957);
#    (0.830720007883271494, -1.98995600838209818);
#    (0.750372059249101886, -2.11306726045741033);
#    (0.609067691518603072, -2.1255665940211288);
#    (0.326337000309732339, -1.75098230545088729);
#    (0.30563483493489868, -1.75404146290737839);
#    (0.987112413290795132, -1.69919479979764221);
#    (0.0870667969862542468, -1.29166998298601232);
#    (0.432524893467385596, -2.08568289959923803);
#    (0.0771964699631442902, -1.31585545811657267);
#    (0.238905930216455481, -1.8093607758768453);
#    (0.303929039665216616, -1.95868412138738424);
#    (0.547817628604677642, -1.98616833975772167);
#    (0.312380861320971481, -1.9720722924197065);
#    (0.805180933815187294, -1.94101119310332471);
#    (0.459472844152303717, -1.90216821676380166);
#    (0.699744618613557, -1.93317910974310436);
#    (0.0526812728993585958, -1.41185401418194356);
#    (0.239753484637530073, -1.68373940673086819);
#    (0.851532148656843, -1.86501917203760792);
#    (0.0219464830195604567, -1.31939250892747451);
#    (0.743930730565400378, -2.14394233892668939);
#    (0.570457673070428828, -2.12677109580082169);
#    (0.895573761624997466, -1.95061385383010433);
#    (0.426178733323951342, -1.88496737743104292);
#    (0.144899771754435081, -1.493878553341905);
#    (0.361478306890748058, -2.03881355512188156);
#    (0.38540145940218723, -1.89404491631937533);
#    (0.315349250245916868, -1.88819624440154965);
#    (0.101509190297779522, -1.38426759857730453);
#    (0.789216514262885749, -2.02855958636022926);
#    (0.0755656446037260288, -1.29372092213588608);
#    (0.194536100165994486, -1.77201683541659016);
#    (0.0449577154203468, -1.40166812011178155);
#    (0.899296062278436392, -1.89673071138148774);
#    (0.744884175191259934, -2.160550493691201);
#    (0.0315332714975545, -1.11712074769025604);
#    (0.672471530568904408, -2.14745690000136147);
#    (0.75046399217971, -2.00983121173884083);
#    (0.226610291935040425, -1.79312502549009434);
#    (0.0382617590706761657, -1.24608103151612282);
#    (0.102046066389680487, -1.48602609504401939);
#    (0.749328819258752499, -2.08239746293259786);
#    (0.28038826477236517, -1.83894762415182167);
#    (0.19669996110265503, -1.7334611514940621);
#    (0.460610508131040708, -2.1123001095517413);
#    (0.561978263807455081, -2.11396834973096714);
#    (0.733889514512473529, -1.95208093486297285);
#    (0.925261605732592418, -1.89570272688413022);
#    (0.624303829659604, -2.06394562356739764);
#    (0.272364918580049409, -1.76106476434035897);
#    (0.923740494661459577, -1.72226523051861635);
#    (0.0419180099458545466, -1.35030327105163028);
#    (0.386667208575989407, -1.97165308540992124);
#    (0.190269279397970337, -1.79096664909143977);
#    (0.130079591285448298, -1.39043164217474535); (0.600381512524197802, ...);
#    ...]
# val x : Matrix.t = <abstr>
# val y : Matrix.t = <abstr>
# val w : float list list =
#   [[-1.13629477224303588]; [-3.10853666014500218]; [2.55495536173983595]]
# val f : float -> float = <fun>

# %%
(* Plot using Archimedes *)
let vp = A. init ~w:600. ~h:600. ["jupyter"] in
    A.Axes.box vp ;
    A.set_color vp A.Color.red ;
    A.List.xy_pairs vp pp ;
    A.set_color vp A.Color.blue ;
    A.fx vp f 0.0 1.0 ;
    A.close vp
# Out:
# - : unit = ()
